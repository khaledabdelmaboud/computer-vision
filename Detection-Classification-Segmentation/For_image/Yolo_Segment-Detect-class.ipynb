# %%
#pip install ultralytics

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
import os 
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
# Load a model (YOLOv8)
model =YOLO(r"C:\Users\hp\Desktop\NTI1\dataset_CV\CODE_SEC\yolov8n-seg.pt") 

# Predict with the model
results = model(r"C:\Users\hp\Desktop\NTI1\dataset_CV\CODE_SEC\IMG_0035.JPG", conf=.6,save=True) 

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\hp\Desktop\NTI1\dataset_CV\CODE_SEC\IMG_0035.JPG: 448x640 8 persons, 97.7ms
# Speed: 4.0ms preprocess, 97.7ms inference, 9.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\segment\predict5
